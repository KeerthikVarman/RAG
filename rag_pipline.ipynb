# %%
##### RAG Pipline  - Data Ingestion to Db ###

# %%
from langchain_community.document_loaders import PyMuPDFLoader
import os
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_652\1328165817.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyMuPDFLoader

# %%
from winreg import ExpandEnvironmentStrings
from importlib.metadata import metadata
def process_all_pdf(pdf_path):
    all_document=[]
    pdf_dir=Path(pdf_path)
    pdf_file=list(pdf_dir.glob("**/*.pdf"))
    print(f"found the {len(pdf_file)}  pdf file to process")
    for pdf_file in pdf_file:
        print(f"{pdf_file.name}")
        try:
            loader=PyMuPDFLoader(str(pdf_file))
            document=loader.load()
            for doc in document:
                metadata['source_file']=pdf_file.name
                metadata['file_type']='pdf'

            all_document.extend(document)
        except Expcetion as e:
            print(f"{e}")
    return all_document
all_pdf_document=process_all_pdf(r"C:\Users\keert\OneDrive\Desktop\RAG\data\pdf")
